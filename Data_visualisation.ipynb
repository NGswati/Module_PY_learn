# %%
#Data Visualisation

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.array([1,5])
y=np.array([20,30])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,"x")
plt.show()

# %%
plt.plot(x,y,"*","r")
plt.show()

# %%
plt.plot(x,y,"*" "r")
plt.show()

# %%
plt.plot(x,y,"*" "r",ms="30")
plt.show()

# %%
plt.plot(x,y,marker="*",color= "r")
plt.show()

# %%
ypoints=np.array([3, 8, 1, 10,12,16])
plt.plot(ypoints, marker = 'o', ms = 30, mec = 'r', color='black')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, linestyle = 'dashed' ,marker='o', mec = 'hotpink',ms=20, mfc= 'blue', linewidth=3)
plt.show()

# %%
ypoints = np.array ( [3, 8, 1, 10])

plt.plot (ypoints, linewidth = 5)
plt.show()

# %%
y1=np.array([1,3,6,9,22])
y2=np.array([2,5,7,9,11,6])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
y1=np.array([1,3,6,9,22])
y2=np.array([2,5,7,9,11,6])
plt.plot(y1,"o" "r")
plt.plot(y2)
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array ([240,250,260, 270, 280, 290, 300, 310, 320, 330])
plt.plot (x, y, color="k", linewidth=3)
plt.xlabel("Average Pulse", fontsize=10,color="red") 
plt.ylabel("Calorie Burnage", fontsize=10,color="g")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array ([240,250,260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.title("Health",color="cyan",fontsize="20")
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array ([240,250,260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.title("Health",color="cyan",fontsize="20")
plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array ([240,250,260, 270, 280, 290, 300, 310, 320, 330])
plt.plot(x,y)
plt.title("Health",color="cyan",fontsize="20")
plt.grid(color="green",linestyle="dotted")
plt.show()

# %%
#Display only grid Lines  y-axis
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 250, 270, 280, 290, 300, 310, 320, 330])
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x, y)
plt.grid(axis = 'y')
plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([2, 8, 1, 10])
plt. subplot (2, 3, 1) 
plt.plot(x,y)

x = np.array ([0, 1, 2, 3])
y = np.array ( [10, 20, 30, 40])
plt. subplot(2, 3, 2) 
plt.plot (x,y)

x = np. array([10, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot (2, 3, 6) 
plt.plot(x,y)

# %%
#plot 1:
x = np. array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot (1, 2, 1) 
plt.plot (x,y)
plt.title("SALES")
#plot 2:
x= np.array ([0, 1, 2, 3])
y = np.array ([10, 20, 30, 40])
plt. subplot (1, 2, 2)
plt.plot (x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
plt.show()

# %%
#day one, the age and speed of 13 cars:
x = np. array([5,7,8,7,2,17,2,9,4, 11,12,9,6])
y = np.array ( [99,86,87,88, 111,86, 103, 87,94,78, 77,85, 86])
plt.scatter(x, y)
#day two, the age and speed of 15 cars:
x = np.array ([2,2,8,1,15,8,12,9,7,3,11,4,7,14, 12])
y = np. array ( [100, 105, 84, 105,90, 99, 90, 95, 94,100, 79, 112,91, 80, 85])
plt.scatter (x, y)
plt.show()

# %%
x = np.random. normal (100,5,2500)
print(x)
plt.hist(x)
plt.show()
# Out:
# [102.2389638  104.03554659 100.14756123 ...  94.59775697  90.50545561
#   96.58906552]

# %%
y = np. array ( [10, 135, 25, 15, 19])
plt.pie (y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples","Baranas", "Cherries", "Dates"]
myexplode = [0,0.95, 0.8, 0.2]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
y = np.array([25,25,25,100])
mylabels = ["Apples","Bananas","Cherries","Dates"]
mycolors = ["black","hotpink","b", "yellow"]
plt.pie(y, labels = mylabels, colors = mycolors, startangle=180)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
#mylabels = ["Apples", "Bananas","Cherries", "Dates"]
plt.pie(y)
plt.legend (labels=mylabels)
plt.show()
